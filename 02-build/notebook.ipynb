# %% [markdown]
# # Module 2: Building with DSPy
#
# Here we will import our modular code and test it.

# %%
import dspy
from agent import RagAgent

# Setup
lm = dspy.LM("openai/gpt-4o-mini")
dspy.settings.configure(lm=lm)

# Dummy retrieval tool
def search_tool(query):
    return "The sky is blue."

agent = RagAgent(retrieval_tool=search_tool)
agent("What color is the sky?")
