# %% [markdown]
# # Module 4: Automatic Improvements
#
# In this notebook, we'll use DSPy to optimize our agent.

# %%
from optimize import optimize_agent
from evaluate import run_evals, validate_answer
# Assume agent is defined or imported
# Assume dev_data is imported from dataset

# 1. Baseline Eval
# score = run_evals(agent, dev_data)
# print(f"Baseline: {score}")

# 2. Optimize
# compiled_agent = optimize_agent(agent, metric=validate_answer)

# 3. Final Eval
# final_score = run_evals(compiled_agent, dev_data)
# print(f"Optimized: {final_score}")
