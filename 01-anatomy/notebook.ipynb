# %% [markdown]
# # Module 1: The Agent Loop
#
# In this notebook, we will prototype the basic control flow of an agent.

# %%
# Pseudo-code for a ReAct loop
def agent_loop(goal):
    messages = [{"role": "user", "content": goal}]
    while True:
        # 1. Call LLM
        # 2. Check for tool calls
        # 3. Execute tools
        # 4. Append results
        pass
